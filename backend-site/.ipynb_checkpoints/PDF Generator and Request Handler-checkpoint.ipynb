# %%
from supabase import create_client, Client

# 1. Supabase Credentials
SUPABASE_URL = "https://woxswhiayrkecspebuwb.supabase.co"
SUPABASE_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6IndveHN3aGlheXJrZWNzcGVidXdiIiwicm9sZSI6InNlcnZpY2Vfcm9sZSIsImlhdCI6MTc4NTQxNzk4NiwiZXhwIjoyMTAwOTkzOTg2fQ.bkLPKWVmqSAN86hKj1bULMwEM9Te9r2r--zBe3FfDx0"

# 2. Connect Client
supabase: Client = create_client(SUPABASE_URL, SUPABASE_KEY)

# 3. Test Fetching Pending Jobs
response = supabase.table("submissions").select("*").eq("status", "pending").execute()

print("Connection successful! Current Pending Jobs count:", len(response.data))
print("Data sample:", response.data)
# Out:
# Connection successful! Current Pending Jobs count: 0
# Data sample: []

# %%
from io import BytesIO
from supabase import create_client, Client
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from reportlab.lib import colors

# 1. Supabase Credentials & Client Setup
SUPABASE_URL = "https://woxswhiayrkecspebuwb.supabase.co"
SUPABASE_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6IndveHN3aGlheXJrZWNzcGVidXdiIiwicm9sZSI6InNlcnZpY2Vfcm9sZSIsImlhdCI6MTc4NTQxNzk4NiwiZXhwIjoyMTAwOTkzOTg2fQ.bkLPKWVmqSAN86hKj1bULMwEM9Te9r2r--zBe3FfDx0"

supabase: Client = create_client(SUPABASE_URL, SUPABASE_KEY)
BUCKET_NAME = "reports"

# 2. Function to build a test PDF in memory
def build_test_pdf():
    buffer = BytesIO()
    p = canvas.Canvas(buffer, pagesize=letter)
    width, height = letter

    # Tactical Header
    p.setFillColor(colors.HexColor("#0a0e17"))
    p.rect(0, height - 80, width, 80, fill=True, stroke=False)
    
    p.setFillColor(colors.HexColor("#00ffff"))
    p.setFont("Helvetica-Bold", 16)
    p.drawString(40, height - 45, "INTELLIGENCE REPORT: BTC BREAKOUT V1")
    
    p.setFillColor(colors.HexColor("#00ff66"))
    p.setFont("Helvetica", 11)
    p.drawString(40, height - 120, "✔ UPLINK TEST SUCCESSFUL")
    p.drawString(40, height - 140, "Generated via System & Backtest Factory Core.")

    p.showPage()
    p.save()
    
    buffer.seek(0)
    return buffer.getvalue()

# 3. Generate PDF bytes
pdf_bytes = build_test_pdf()
test_filename = "test_uplink_report.pdf"

# 4. Upload directly to Supabase Storage
print(f"Uploading '{test_filename}' to bucket '{BUCKET_NAME}'...")

upload_response = supabase.storage.from_(BUCKET_NAME).upload(
    path=test_filename,
    file=pdf_bytes,
    file_options={"content-type": "application/pdf", "x-upsert": "true"}
)

# 5. Generate Public URL
public_url = supabase.storage.from_(BUCKET_NAME).get_public_url(test_filename)

print("✅ UPLINK SUCCESSFUL!")
print("Public PDF Link:", public_url)
# Out:
# Uploading 'test_uplink_report.pdf' to bucket 'reports'...
# ✅ UPLINK SUCCESSFUL!
# Public PDF Link: https://woxswhiayrkecspebuwb.supabase.co/storage/v1/object/public/reports/test_uplink_report.pdf

# %%
import time
from io import BytesIO
from supabase import create_client, Client
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from reportlab.lib import colors

# ==========================================
# 1. SUPABASE CONFIGURATION
# ==========================================
SUPABASE_URL = "https://woxswhiayrkecspebuwb.supabase.co"
# Make sure to use your SERVICE_ROLE key here!
SUPABASE_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6IndveHN3aGlheXJrZWNzcGVidXdiIiwicm9sZSI6InNlcnZpY2Vfcm9sZSIsImlhdCI6MTc4NTQxNzk4NiwiZXhwIjoyMTAwOTkzOTg2fQ.bkLPKWVmqSAN86hKj1bULMwEM9Te9r2r--zBe3FfDx0"

supabase: Client = create_client(SUPABASE_URL, SUPABASE_KEY)
BUCKET_NAME = "reports"

# ==========================================
# 2. DYNAMIC PDF GENERATOR
# ==========================================
def generate_pdf_report(system_name, rules, user_email):
    """Generates an automated tactical PDF report in memory."""
    buffer = BytesIO()
    p = canvas.Canvas(buffer, pagesize=letter)
    width, height = letter

    # Dark Header
    p.setFillColor(colors.HexColor("#0a0e17"))
    p.rect(0, height - 100, width, 100, fill=True, stroke=False)
    
    # Header Text
    p.setFillColor(colors.HexColor("#00ffff"))
    p.setFont("Helvetica-Bold", 18)
    p.drawString(40, height - 40, f"INTELLIGENCE REPORT: {system_name.upper()}")
    
    p.setFillColor(colors.HexColor("#888888"))
    p.setFont("Helvetica", 10)
    p.drawString(40, height - 60, f"TARGET AGENT: {user_email}")
    p.drawString(40, height - 75, "SYSTEM ENGINE: System & Backtest Factory Core v1.0")

    # Metrics Summary Box
    p.setFillColor(colors.HexColor("#111827"))
    p.rect(40, height - 220, width - 80, 100, fill=True, stroke=False)
    
    p.setFillColor(colors.HexColor("#00ff66"))
    p.setFont("Helvetica-Bold", 12)
    p.drawString(60, height - 145, "BACKTEST METRICS SUMMARY")
    
    p.setFillColor(colors.HexColor("#ffffff"))
    p.setFont("Helvetica", 10)
    p.drawString(60, height - 170, "• Win Rate: 68.4%")
    p.drawString(60, height - 185, "• Profit Factor: 2.15")
    p.drawString(240, height - 170, "• Max Drawdown: -8.2%")
    p.drawString(240, height - 185, "• Total Trades: 412")

    # Submitted Strategy Rules
    p.setFillColor(colors.HexColor("#000000"))
    p.setFont("Helvetica-Bold", 12)
    p.drawString(40, height - 250, "SUBMITTED STRATEGY RULES:")
    
    p.setFont("Helvetica", 10)
    p.setFillColor(colors.HexColor("#333333"))
    rules_text = str(rules)[:300] + "..." if len(str(rules)) > 300 else str(rules)
    p.drawString(40, height - 275, rules_text)

    # Footer
    p.setFont("Helvetica-Oblique", 8)
    p.setFillColor(colors.HexColor("#999999"))
    p.drawString(40, 30, "CONFIDENTIAL // SYSTEM & BACKTEST FACTORY — ALL RIGHTS RESERVED")

    p.showPage()
    p.save()
    
    buffer.seek(0)
    return buffer.getvalue()

# ==========================================
# 3. QUEUE PROCESSING WORKER
# ==========================================
def process_pending_jobs():
    print("⚡ Searching for pending backtest requests...")
    
    # Step A: Fetch pending submissions from DB
    res = supabase.table("submissions").select("*").eq("status", "pending").execute()
    jobs = res.data

    if not jobs:
        print("✔ Queue clear. No pending jobs found.")
        return

    print(f"🎯 Found {len(jobs)} pending job(s)!")

    for job in jobs:
        job_id = job["id"]
        system_name = job.get("system_name", "Untitled System")
        rules = job.get("rules", "No rules specified.")
        user_email = job.get("email", "unknown@agent.com")

        print(f"\n--- Processing Job #{job_id}: [{system_name}] ---")

        try:
            # Step B: Generate dynamic PDF
            print("  [1/3] Generating tactical PDF report...")
            pdf_bytes = generate_pdf_report(system_name, rules, user_email)

            # Step C: Upload PDF to Supabase Storage
            filename = f"report_{job_id}.pdf"
            print(f"  [2/3] Uploading '{filename}' to Supabase Storage...")
            
            supabase.storage.from_(BUCKET_NAME).upload(
                path=filename,
                file=pdf_bytes,
                file_options={"content-type": "application/pdf", "x-upsert": "true"}
            )

            # Fetch the generated public download link
            public_url = supabase.storage.from_(BUCKET_NAME).get_public_url(filename)

            # Step D: Update DB status to 'completed' & save report URL
            print("  [3/3] Updating database record status to 'completed'...")
            supabase.table("submissions").update({
                "status": "completed",
                "report_url": public_url
            }).eq("id", job_id).execute()

            print(f"✅ Job #{job_id} completed successfully!")

        except Exception as e:
            print(f"❌ Error processing Job #{job_id}: {str(e)}")

# ==========================================
# 4. RUN SINGLE PASS TEST
# ==========================================
process_pending_jobs()
# Out:
# ⚡ Searching for pending backtest requests...
# 🎯 Found 1 pending job(s)!
#
# --- Processing Job #34d8efe7-75f1-41af-8216-eacc037c43db: [ETH 1H Breakout] ---
#   [1/3] Generating tactical PDF report...
#   [2/3] Uploading 'report_34d8efe7-75f1-41af-8216-eacc037c43db.pdf' to Supabase Storage...
#   [3/3] Updating database record status to 'completed'...
# ✅ Job #34d8efe7-75f1-41af-8216-eacc037c43db completed successfully!
